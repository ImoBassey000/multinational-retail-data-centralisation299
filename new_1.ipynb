# %%
from data_extration import DataExtractor
import pandas as pd
import numpy as np
import datetime as datetime

# %%
DataExtract = DataExtractor()

legacy_users_df = DataExtract.read_rds_table('legacy_users')
legacy_users_df.head()
# Out:
#    index first_name last_name date_of_birth                    company  \
# 0      0   Sigfried     Noack    1990-09-30         Heydrich Junitz KG
# 1      1        Guy     Allen    1940-12-01                    Fox Ltd
# 2      2      Harry  Lawrence    1995-08-02  Johnson, Jones and Harris
# 3      3     Darren   Hussain    1972-09-23                Wheeler LLC
# 4      4      Garry     Stone    1952-12-20                 Warner Inc
#
#                   email_address  \
# 0             rudi79@winkler.de
# 1  rhodesclifford@henderson.com
# 2  glen98@bryant-marshall.co.uk
# 3    daniellebryan@thompson.org
# 4       billy14@long-warren.com
#
#                                              address         country  \
# 0                       Zimmerstr. 1/0\n59015 Gießen         Germany
# 1  Studio 22a\nLynne terrace\nMcCarthymouth\nTF0 9GH  United Kingdom
# 2                 92 Ann drive\nJoanborough\nSK0 6LR  United Kingdom
# ...

# %%
legacy_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15320 entries, 0 to 15319
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          15320 non-null  int64
#  1   first_name     15320 non-null  object
#  2   last_name      15320 non-null  object
#  3   date_of_birth  15320 non-null  object
#  4   company        15320 non-null  object
#  5   email_address  15320 non-null  object
#  6   address        15320 non-null  object
#  7   country        15320 non-null  object
#  8   country_code   15320 non-null  object
#  9   phone_number   15320 non-null  object
#  10  join_date      15320 non-null  object
#  11  user_uuid      15320 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.4+ MB

# %%
legacy_users_df['company'].value_counts()
# Out:
# company
# Smith Inc                     22
# Smith Ltd                     21
# NULL                          21
# Smith and Sons                20
# Smith PLC                     18
#                               ..
# Tschentscher GbR               1
# Cooper-Thomas                  1
# Campbell-Bell                  1
# Mälzer Lehmann GbR             1
# Phillips, Brown and Powell     1
# Name: count, Length: 12105, dtype: int64

# %%
var_1 = list(legacy_users_df['join_date'].unique())
var_1
# Out:
# ['2018-10-10',
#  '2001-12-20',
#  '2016-12-16',
#  '2004-02-23',
#  '2006-09-01',
#  '2002-01-21',
#  '2004-06-23',
#  '2008-04-19',
#  '1993-07-10',
#  '1998-05-15',
#  '2007-04-22',
#  '2017-09-11',
#  '2018-02-06',
#  '2006-07-21',
#  '2001-09-22',
#  '2022-05-21',
#  '2007-03-20',
#  '2021-02-24',
#  '2015-03-16',
#  '2007-07-07',
#  '2001-04-30',
#  '2006-02-04',
#  '1997-12-19',
#  '2001-04-07',
#  '2010-10-12',
#  '2016-01-02',
#  '1994-08-14',
#  '2001-09-23',
#  '2004-02-06',
#  '2012-10-19',
#  '2015-08-05',
#  '2001-06-15',
#  '2015-03-15',
#  '1995-02-05',
#  '2000-07-18',
#  '2007-01-05',
#  '2017-06-27',
#  '2012-04-28',
#  '2007-09-04',
#  '1996-02-26',
#  '2012-12-12',
#  '1993-11-07',
#  '2009-05-11',
#  '2009-04-16',
#  '2005-10-09',
#  '2017-03-11',
#  '2020-03-30',
#  '2020-01-29',
#  '1996-11-16',
#  '2008-05-21',
#  '1996-05-18',
#  '2016-07-18',
#  '2008-05-03',
#  '2009-06-02',
#  '2011-03-28',
#  '2012-02-09',
#  '2007-10-31',
#  '2004-08-19',
# ...

# %%
legacy_users_df['join_date'] = pd.to_datetime(legacy_users_df['join_date'], errors='coerce')

# %%
legacy_users_df = legacy_users_df.dropna(subset=['join_date'])

# %%
legacy_users_df['join_date'] = legacy_users_df['join_date'].dt.date

# %%
var_2 = list(legacy_users_df['date_of_birth'].unique())
var_2
# Out:
# ['1990-09-30',
#  '1940-12-01',
#  '1995-08-02',
#  '1972-09-23',
#  '1952-12-20',
#  '1949-08-12',
#  '1952-11-10',
#  '2006-08-05',
#  '1959-11-13',
#  '1992-10-09',
#  '1956-11-09',
#  '1955-02-20',
#  '1987-11-08',
#  '1963-07-17',
#  '1977-12-27',
#  '1971-09-10',
#  '1988-11-02',
#  '1994-06-05',
#  '1966-01-08',
#  '2003-06-10',
#  '1998-06-02',
#  '1940-11-04',
#  '1944-05-07',
#  '1999-02-18',
#  '2005-02-22',
#  '1951-04-15',
#  '1981-07-19',
#  '1979-07-29',
#  '1989-05-03',
#  '1983-04-07',
#  '1968-01-09',
#  '1944-05-25',
#  '1985-08-18',
#  '1971-12-02',
#  '1949-10-06',
#  '1946-06-30',
#  '1996-10-26',
#  '1999-01-29',
#  '1950-05-22',
#  '2006-08-24',
#  '1955-06-28',
#  '1991-04-29',
#  '1991-04-03',
#  '1943-04-22',
#  '1947-01-05',
#  '1990-08-10',
#  '1951-03-05',
#  '1983-02-10',
#  '1978-10-01',
#  '1950-06-21',
#  '1950-12-09',
#  '1967-04-26',
#  '1977-02-12',
#  '2004-10-23',
#  '1969-08-19',
#  '1971-02-09',
#  '1980-12-13',
#  '1998-10-28',
# ...

# %%
legacy_users_df['date_of_birth'] = pd.to_datetime(legacy_users_df['date_of_birth'], errors='coerce')
legacy_users_df = legacy_users_df.dropna(subset=['date_of_birth'])
legacy_users_df['date_of_birth'] = legacy_users_df['date_of_birth'].dt.date

# %%
var_2 = list(legacy_users_df['date_of_birth'].unique())
var_2
# Out:
# [datetime.date(1990, 9, 30),
#  datetime.date(1940, 12, 1),
#  datetime.date(1995, 8, 2),
#  datetime.date(1972, 9, 23),
#  datetime.date(1952, 12, 20),
#  datetime.date(1949, 8, 12),
#  datetime.date(1952, 11, 10),
#  datetime.date(2006, 8, 5),
#  datetime.date(1959, 11, 13),
#  datetime.date(1992, 10, 9),
#  datetime.date(1956, 11, 9),
#  datetime.date(1955, 2, 20),
#  datetime.date(1987, 11, 8),
#  datetime.date(1963, 7, 17),
#  datetime.date(1977, 12, 27),
#  datetime.date(1971, 9, 10),
#  datetime.date(1988, 11, 2),
#  datetime.date(1994, 6, 5),
#  datetime.date(1966, 1, 8),
#  datetime.date(2003, 6, 10),
#  datetime.date(1998, 6, 2),
#  datetime.date(1940, 11, 4),
#  datetime.date(1944, 5, 7),
#  datetime.date(1999, 2, 18),
#  datetime.date(2005, 2, 22),
#  datetime.date(1951, 4, 15),
#  datetime.date(1981, 7, 19),
#  datetime.date(1979, 7, 29),
#  datetime.date(1989, 5, 3),
#  datetime.date(1983, 4, 7),
#  datetime.date(1968, 1, 9),
#  datetime.date(1944, 5, 25),
# ...

# %%
var_3 = list(legacy_users_df['phone_number'])
var_3
# Out:
# ['+49(0) 047905356',
#  '(0161) 496 0674',
#  '+44(0)121 4960340',
#  '(0306) 999 0871',
#  '0121 496 0225',
#  '277-664-6389x8405',
#  '028 9018749',
#  '+44(0)1414960221',
#  '028 9018 0338',
#  '6554215915',
#  '+44141 496 0404',
#  '(0114) 496 0775',
#  '(028) 9018 0333',
#  '+49(0)9775 74337',
#  '+49(0)0406372221',
#  '+441174960765',
#  '572.068.8397',
#  '(0114) 4960518',
#  '08346 147221',
#  '+44306 9990447',
#  '+44(0)1614960247',
#  '+49 (0) 9914 457670',
#  '(0151) 4960510',
#  '+44(0)808 157 0714',
#  '029 2018 0952',
#  '(0117) 496 0586',
#  '03069990628',
#  '(987)576-3015x3130',
#  '(0151) 4960784',
#  '+44(0)117 496 0576',
#  '+49 (0) 5932 078914',
#  '+49(0)1338 672811',
#  '+44909 879 0133',
#  '0117 4960692',
#  '03381 12459',
#  '723-654-4681x6799',
#  '+44306 9990216',
#  '+49(0) 438105334',
#  '872.200.3110x563',
#  '00450208239',
#  '+44(0)1214960207',
#  '0151 4960967',
#  '(0151) 4960666',
#  '+49(0)2097188499',
#  '028 9018572',
#  '+441164960437',
# ...
